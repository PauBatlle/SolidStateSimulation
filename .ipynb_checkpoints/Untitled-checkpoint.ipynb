# %%
# %run main.py --input InputsExpAdam/AdamProva --timestep 1e-3 --niter 5000
# Out:
# 2018-04-19 09:42:40,816 main Començant Experiment
# 2018-04-19 09:42:40,817 input_reader Llegint dades d'entrada
# 2018-04-19 09:42:40,818 input_reader El model AdamProva s'ha llegit correctament
# 2018-04-19 09:42:40,819 main Començant simulació, 5000 iteracions, timestep = 0.001
# 100%|██████████| 5000/5000 [00:00<00:00, 26074.12it/s]
# 2018-04-19 09:42:41,014 main

# %%
npart = exp.positions.shape[0]
niter = exp.positions.shape[2]
pos = exp.positions

# %%
pos[1,:,999]
# Out:
# array([-1.00004221,  0.20657159,  0.        ])

# %%
pos[0,:,999]
# Out:
# array([-0.00195779, -0.00657159,  0.        ])

# %%
pos.shape
# Out:
# (2, 3, 10000)

# %%
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from IPython.display import HTML


skip = 10
stop = 5000
    print(str(stop/skip), end = '\n')
colors = np.linspace(0, 1, npart)

def _update_plot(i, fig, scat):
    scat.set_offsets(tuple([[pos[j,0,skip*i], pos[j,1,skip*i]] for j in range(npart)]))
    #print('Frames: %d', %i) # For < Python3 
    #print('Frames: {}'.format(i)) # For Python3
    print(i,end = '\r')
    return scat

fig = plt.figure()

x = pos[:,0,0]
y = pos[:,1,0]
ax = fig.add_subplot(111)
#ax.grid(True, linestyle = '-', color = '0.75')
ax.set_xlim([np.min(pos[:,0]), np.max(pos[:,0])])
ax.set_ylim([np.min(pos[:,1]), np.max(pos[:,1])])

scat = plt.scatter(x, y, c = colors)

fps = 200

anim = animation.FuncAnimation(fig, _update_plot, fargs = (fig, scat), frames = int(stop/skip)-1, interval = 10)
anim.save('2part_example.mp4', writer="ffmpeg")
HTML(anim.to_jshtml())
# Out:
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 500.0
# 375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-88-2004ebd5f95c> in <module>()
#      31
#      32 anim = animation.FuncAnimation(fig, _update_plot, fargs = (fig, scat), frames = int(stop/skip)-1, interval = 10)
# ---> 33 anim.save('2part_example.mp4', writer="ffmpeg")
#      34 HTML(anim.to_jshtml())
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1258                         # TODO: See if turning off blit is really necessary
#    1259                         anim._draw_next_frame(d, blit=False)
# -> 1260                     writer.grab_frame(**savefig_kwargs)
#    1261
#    1262         # Reconnect signal for first draw if necessary
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/animation.py in grab_frame(self, **savefig_kwargs)
#     386             # frame format and dpi.
#     387             self.fig.savefig(self._frame_sink(), format=self.frame_format,
# --> 388                              dpi=self.dpi, **savefig_kwargs)
#     389         except (RuntimeError, IOError) as e:
#     390             out, err = self._proc.communicate()
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py in savefig(self, fname, **kwargs)
#    1812             self.set_frameon(frameon)
#    1813
# -> 1814         self.canvas.print_figure(fname, **kwargs)
#    1815
#    1816         if frameon:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2257                 orientation=orientation,
#    2258                 bbox_inches_restore=_bbox_inches_restore,
# -> 2259                 **kwargs)
#    2260         finally:
#    2261             if bbox_inches and restore_bbox:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in print_raw(self, filename_or_obj, *args, **kwargs)
#     486
#     487     def print_raw(self, filename_or_obj, *args, **kwargs):
# --> 488         FigureCanvasAgg.draw(self)
#     489         renderer = self.get_renderer()
#     490         original_dpi = renderer.dpi
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     428             if toolbar:
#     429                 toolbar.set_cursor(cursors.WAIT)
# --> 430             self.figure.draw(self.renderer)
#     431         finally:
#     432             if toolbar:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1290
#    1291             if self.frameon:
# -> 1292                 self.patch.draw(renderer)
#    1293
#    1294             mimage._draw_list_compositing_images(
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      53                 renderer.start_filter()
#      54
# ---> 55             return draw(artist, renderer, *args, **kwargs)
#      56         finally:
#      57             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/patches.py in draw(self, renderer)
#     572             renderer = PathEffectRenderer(self.get_path_effects(), renderer)
#     573
# --> 574         renderer.draw_path(gc, tpath, affine, rgbFace)
#     575
#     576         gc.restore()
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in draw_path(self, gc, path, transform, rgbFace)
#     163         else:
#     164             try:
# --> 165                 self._renderer.draw_path(gc, path, transform, rgbFace)
#     166             except OverflowError:
#     167                 raise OverflowError("Exceeded cell block limit (set 'agg.path.chunksize' rcparam)")
#
# KeyboardInterrupt:
